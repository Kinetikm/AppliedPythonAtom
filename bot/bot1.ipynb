# %%
import itertools
import numpy as np
import pandas as pd
from annoy import AnnoyIndex
from gensim.models.word2vec import Word2Vec
import pickle as pkl

# %%
Product_dict = pkl.load(open('Product_dict.pkl', 'rb'))
data = pd.read_csv('data_1.csv')
data=data.applymap(str)
data.drop(data.columns[data.columns.str.contains('unnamed',case = False)],axis = 1, inplace = True)
model = Word2Vec.load('./hackaton.w2v_gensim3')
model.similar_by_vector(model['1260627'] )
data_storage = {i[1]['product_id']:i[1]['id'] for i in data.iterrows()}
index_img_emb = AnnoyIndex(100)
index_img_emb.load('./hackaton_annoy_30')
map_id_hashimg = pkl.load(open('hackaton_map_id_to_hash_products.dict5', 'rb'))
index_img_emb1= AnnoyIndex(100)
index_img_emb1.load('./hackaton_annoy_100')
map_id_hashimg1 = pkl.load(open('hackaton_map_id_to_hash_products.dict100', 'rb'))
prod1 = pd.read_csv('prod111.csv')
prod1.fillna(value='', inplace=True)
prod1=prod1.applymap(str)
prod1.drop(prod1.columns[prod1.columns.str.contains('unnamed',case = False)],axis = 1, inplace = True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   import sys
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: DeprecationWarning: Call to deprecated `similar_by_vector` (Method will be removed in 4.0.0, use self.wv.similar_by_vector() instead).
#   import sys

# %%
data
# Out:
#       sale_date_date product_id  \
# 0         2018-12-07     168308
# 1         2018-12-07     134832
# 2         2018-12-07     101384
# 3         2018-12-07     168570
# 4         2018-12-07     168319
# 5         2018-12-07      37505
# 6         2018-12-07     168570
# 7         2018-12-07     168308
# 8         2018-12-07     134832
# 9         2018-12-07     168308
# 10        2018-12-07     146960
# 11        2018-12-07     168570
# 12        2018-12-07     158662
# 13        2018-12-07     168308
# 14        2018-12-07     168308
# 15        2018-12-08     146960
# 16        2018-12-08     168308
# 17        2018-12-08     128700
# 18        2018-12-08     168308
# 19        2018-12-08      52539
# 20        2018-12-08      94270
# 21        2018-12-08      77426
# 22        2018-12-08      94270
# 23        2018-12-08      92475
# 24        2018-12-08     168570
# 25        2018-12-08     158643
# 26        2018-12-08     158600
# 27        2018-12-08     106230
# 28        2018-12-08     110629
# 29        2018-12-08      89410
# ...              ...        ...
# 99970     2018-12-07     159987
# 99971     2018-12-07      70496
# 99972     2018-12-07      62245
# 99973     2018-12-07     129684
# 99974     2018-12-07      61944
# 99975     2018-12-07      98037
# 99976     2018-12-07     157729
# 99977     2018-12-07      93069
# 99978     2018-12-07     147198
# 99979     2018-12-07     124688
# 99980     2018-12-07     155923
# 99981     2018-12-07      82367
# 99982     2018-12-07     107192
# 99983     2018-12-07      62521
# 99984     2018-12-07     141946
# 99985     2018-12-07      56727
# 99986     2018-12-07      82882
# 99987     2018-12-07      83201
# 99988     2018-12-07      28232
# 99989     2018-12-07      32834
# 99990     2018-12-07     163810
# 99991     2018-12-07      73742
# 99992     2018-12-07     165490
# 99993     2018-12-07      90936
# 99994     2018-12-07     148022
# 99995     2018-12-07     135428
# 99996     2018-12-07     143610
# 99997     2018-12-07     150460
# 99998     2018-12-07     148081
# 99999     2018-12-07      62393
#
#                                                     name  \
# 0                                    Пакет-майка см х см
# 1        Перекись водорода р-р наружн. % фл.полимерн. мл
# 2                Салициловая кислота р-р спирт % фл мл N
# 3                                          Пакет см х см
# 4                                          Пакет см х см
# 5                                  Кеппра таб.п.п.о.мг №
# 6                                          Пакет см х см
# 7                                    Пакет-майка см х см
# 8        Перекись водорода р-р наружн. % фл.полимерн. мл
# 9                                    Пакет-майка см х см
# 10                           Пакет "Аптека Озерки"  х см
# 11                                         Пакет см х см
# 12                               Карта Забота о Здоровье
# 13                                   Пакет-майка см х см
# 14                                   Пакет-майка см х см
# 15                           Пакет "Аптека Озерки"  х см
# 16                                   Пакет-майка см х см
# 17                                  Ранитидин тб мг уп N
# 18                                   Пакет-майка см х см
# 19                          Платки носовые "Зева Кидс" №
# 20                                                х см №
# 21                Иглы Микро-Файн д/шприц-ручки G ,*мм N
# 22                                                х см №
# 23                Дорзопт капли глазные % мл. фл.-кап. N
# 24                                         Пакет см х см
# 25                      PL Шприц одноразовый -комп. мл №
# 26                      PL Шприц одноразовый -комп. мл №
# 27                                     Аллапинин тб мг N
# 28                     Корвалол капли д/приема внутрь мл
# 29                                        Азафен тб мг №
# ...                                                  ...
# 99970   Валемидин капли для приема внутрь спиртовые ф...
# 99971                                                nan
# 99972           Кальция глюконат-Виал р-р д/и % амп мл N
# 99973                        Циннаризин Авексима тб мг N
# 99974           Микодерил р-р д/наружн.прим.% фл.-кап.мл
# 99975                                Бетагистин таб.мг №
# 99976               Аквалор беби спрей наз. для детей мл
# 99977   Отофа ушные капли фл мл с пипеткой-капельницей N
# 99978   Косопт капли глазные мг + мг/мл  фл-капел мл ...
# 99979                       Офтальмоферон гл. капли мл №
# 99980                               Верошпирон капс.мг №
# 99981                           Детралекс таб.п.п.о.мг №
# 99982                           Йода р-р спирт % фл мл N
# 99983                Корнерегель глазной гель % туба г N
# 99984                           Октолипен таб.п.п.о.мг №
# 99985                                 Гипосарт таб. мг №
# 99986                  Тест-кассета  Accu-chek  Мобайл №
# 99987                 Азарга капли глазные мл фл.-кап. №
# 99988                                Верошпирон таб.мг №
# 99989                                     Омез капс мг N
# 99990                Омник Окас таб.п.о.контр.высв..мг №
# 99991                                   Гидреа капс.мг N
# 99992                            Биматан кап.глаз.,% ,мл
# 99993                                Урсофальк капс мг N
# 99994                                     Эгилок тб мг N
# 99995                   Фокусин капс.с модиф.высв. ,мг №
# 99996                          Тирозол табл. п.о.  мг. №
# 99997                        р-р д/наруж.прим..% фл.мл №
# 99998                                    Хофитол тб .г N
# 99999     Бронхо Веда леденцы на травяной основе Лимон №
#
#       product_sub_category_id brand_id quantity                id
# 0                         906       -1     1,00  1260627 1455 205
# 1                         404       -1     1,00     198287 279 93
# 2                         404       -1     1,00    2418385 848 93
# 3                         906       -1     1,00  1285774 1511 205
# 4                         906       -1     1,00  1810323 1501 205
# 5                         641       -1     1,00    2435604 66 146
# 6                         906       -1     1,00  1697532 1504 205
# 7                         906       -1     1,00  1779333 1455 205
# 8                         404       -1     1,00     507339 275 93
# 9                         906       -1     1,00  1533558 1462 205
# 10                        906       -1     1,00  2030547 1146 205
# 11                        906       -1     1,00  1940123 1495 205
# 12                        855       -1     1,00    785614 859 194
# 13                        906       -1     1,00  1301620 1471 205
# 14                        906       -1     1,00  1455298 1495 205
# 15                        906       -1     1,00  2520496 1004 205
# 16                        906       -1     1,00  1300685 1918 205
# 17                        595       -1     2,00    514490 350 135
# 18                        906       -1     1,00  1493592 1516 205
# 19                        721     3421     2,00   2109210 324 167
# 20                         -1       -1     1,00    1993783 303 -1
# 21                        759     2101     0,12   2742478 105 176
# 22                         -1       -1     1,00    2480204 303 -1
# 23                        575       -1    0,004     87961 596 129
# 24                        906       -1     1,00  2650451 1496 205
# 25                        762     1520     2,00   2650603 840 176
# 26                        762     1520    20,00   2605787 457 176
# 27                        738       -1     2,00    364724 268 170
# 28                        738       -1     2,00    364724 268 170
# 29                        635       -1     2,00  1347624 1495 146
# ...                       ...      ...      ...               ...
# 99970                     613       -1     1,00   1205575 144 140
# 99971                     397       -1     1,00    1075439 946 90
# 99972                     439       -1     1,00    758848 832 101
# 99973                     639       -1     1,00    912388 913 146
# 99974                     622       -1     1,00     77162 350 142
# 99975                     639       -1     1,00    252251 320 146
# 99976                     698     2531     1,00    100723 344 162
# 99977                     697       -1     1,00    515743 275 162
# 99978                     575       -1     1,00   1087581 327 129
# 99979                     575       -1     1,00    182142 328 129
# 99980                     735       -1     1,00    421040 323 170
# 99981                     736       -1     1,00   418148 1534 170
# 99982                     404       -1     1,00      556654 59 93
# 99983                     575       -1     1,00     472545 57 129
# 99984                     596       -1     1,00    597822 319 135
# 99985                     738       -1     1,00     97640 244 170
# 99986                     452     2538     1,00     63312 311 106
# 99987                     575       -1     1,00   2209020 363 129
# 99988                     735       -1     1,00    723275 608 170
# 99989                     595       -1     1,00   498734 2156 135
# 99990                     627       -1     1,00    216665 349 144
# 99991                     642       -1     1,00    780054 538 147
# 99992                     575       -1     1,00    216156 307 129
# 99993                     596       -1     1,00    160541 323 135
# 99994                     738       -1     1,00   1143541 598 170
# 99995                     627       -1     1,00    201801 321 144
# 99996                     459       -1     1,00   2610369 907 108
# 99997                     583       -1     1,00   2454531 596 130
# 99998                     595       -1     1,00   2025602 110 135
# 99999                     700     2883     1,00    336647 849 162
#
# [100000 rows x 7 columns]

# %%
prod1
# Out:
#         index                                                  0
# 0      168308                               Пакет-майка см х см
# 1      134832   Перекись водорода р-р наружн. % фл.полимерн. мл
# 2      101384           Салициловая кислота р-р спирт % фл мл N
# 3      168570                                     Пакет см х см
# 4      146960                       Пакет "Аптека Озерки"  х см
# 5      128700                              Ранитидин тб мг уп N
# 6       52539                      Платки носовые "Зева Кидс" №
# 7       94270                                           х см № -
# 8       77426            Иглы Микро-Файн д/шприц-ручки G ,*мм N
# 9       92475            Дорзопт капли глазные % мл. фл.-кап. N
# 10     158643                  PL Шприц одноразовый -комп. мл №
# 11     158600                  PL Шприц одноразовый -комп. мл №
# 12     106230                                 Аллапинин тб мг N
# 13     110629                 Корвалол капли д/приема внутрь мл
# 14      47251   PL Контейнер д/биопроб стер. мл с крыш и ложк...
# 15      39811       PL Салфетка антисептическая спиртовая хсм №
# 16     143709                PL вода питьевая негазированная мл
# 17      25965                      Калия перманганат пор фл г N
# 18     158645                  PL Шприц одноразовый -комп. мл №
# 19      79879                                 Азитрал капс мг N
# 20     100667        PL Аскорбиновая кислота с глюкозой тб мг №
# 21      87332    Сульфацил натрия капли глазн % тюб-капел .мл N
# 22      21249                                 Горчичник пакет N
# 23     158659                  PL Шприц одноразовый -комп. мл №
# 24      76206                     Трусопт капли глазн % мл фл N
# 25     114366                               Винпоцетин таб.мг №
# 26      34531                    Глюкованс табл. п.о.  мг/ мг №
# 27      27063                       Нафтизин р-р .% фл/кап мл N
# 28      20236                              Линекс Форте капс. №
# 29      99525                       Смекта Апельсин пор.  гр. N
# ...       ...                                                ...
# 30388  192523                                         название -
# 30389  159438   Пластырь "Omnifix" гипоаллерг. фикс. из нетка...
# 30390  192645                                         название -
# 30391   17927                       Масло льняное с селеном мл -
# 30392  192588                                         название -
# 30393  112602   АзитРус пор.д/приг.сусп.д/приема внутрь мг па...
# 30394   36181   Шоллей Синастон крем для бюста д/укрепления г...
# 30395   37478          Кальция глюконат-Виал р-р д/и % амп мл N
# 30396  152472                           Нарин Тоник для лица мл
# 30397   95571    Катетер Игла-Бабочка д/вливания в малые вены G
# 30398   67685                      Грудной эликсир жидк фл мл N
# 30399  141828              Сбор противогеморроидальный ф/п г № -
# 30400  164748
# 30401  153665   Очки корригирующие Кемнер Оптикс глянцевые пл...
# 30402  164193                          Лактулоза форте пор.мл №
# 30403  153013   Курапрокс Набор (зубная паста Вайт Из Блэк мл...
# 30404   59719
# 30405  193449                                         название -
# 30406  193439                                         название -
# 30407  193569                                         название -
# 30408  193556                                         название -
# 30409  193559                                         название -
# 30410  103197   Бельведер Тушь д/ресниц антибактериальная кре...
# 30411  192542                                         название -
# 30412  193512                                         название -
# 30413  193603                                         название -
# 30414  193484                                         название -
# 30415  192459                                         название -
# 30416  193510                                         название -
# 30417  192468                                         название -
#
# [30418 rows x 2 columns]

# %%
def request_id(a=134832):
    pr=data.loc[data['product_id'] == str(a)]
    pr.reset_index(inplace=True,drop=False)
    vector=pr['id'][0]

    vec = np.zeros(100)
    for word in vector.split(' '):
        if word in model:
            vec+=model[word] 

    data_storage_norm1 = vec
    annoy_res = list(index_img_emb.get_nns_by_vector(data_storage_norm1, 13, include_distances=True,search_k=10000))
    print('\n\nСоседи:')
    a=list()
    for annoy_id, annoy_sim in itertools.islice(zip(*annoy_res), 13):
        image_id = map_id_hashimg[annoy_id]
   # print(image_id)
    #print(data_storage[image_id], 1 - annoy_sim ** 2 / 2)
        a.append(list(prod1.loc[prod1['index'] == str(image_id)]['0']))
        
    return a

# %%
a=request_id()
# Out:
# Соседи:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   if __name__ == '__main__':

# %%
a
# Out:
# [[' Колдрекс ХотРем Мед-Лимон пор.д/приг.р-ра д/приема внутрь пак.№ '],
#  [' Панадол детский сусп.д/приема внутрь мг/мл фл.мл № '],
#  [' Тантум верде р-р д/полоскания рта фл мл N '],
#  [' Нурофен для детей сусп.д/приема внутрь мг/мл с клубникой фл.мл № '],
#  [' Длянос спрей наз.  мг/мл. фл. с пульв.  мл. '],
#  [' Вольтарен табл. п.о. раствор./кишечн.  мг. № '],
#  [' Некст Уно Экспресс капс.мг № '],
#  [' Нурофен тб п.о.мг N д/детей '],
#  [' Найз таб.мг № '],
#  [' Опти-Фри Экспресс раствор д/линз многофункциональный мл N '],
#  [' Келтикан комплекс капс.№ '],
#  [' Нэйчес Баунти Витамин Д МЕ таб.№ '],
#  [' Магний плюс шип тб N ']]

# %%
def request_id_1(a=134832):
    pr=data.loc[data['product_id'] == str(a)]
    pr.reset_index(inplace=True,drop=False)
    vector=pr['id'][0]

    vec = np.zeros(100)
    for word in vector.split(' '):
        if word in model:
            vec+=model[word] 

    data_storage_norm1 = vec
    annoy_res = list(index_img_emb1.get_nns_by_vector(data_storage_norm1, 13, include_distances=True,search_k=10000))
    print('\n\nСоседи:')
    a=list()
    for annoy_id, annoy_sim in itertools.islice(zip(*annoy_res), 13):
        image_id = map_id_hashimg1[annoy_id]
   # print(image_id)
    #print(data_storage[image_id], 1 - annoy_sim ** 2 / 2)
        a.append(list(prod1.loc[prod1['index'] == str(image_id)]['0']))
        
    return a

# %%
request_id_1()
# Out:
# Соседи:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   if __name__ == '__main__':
# [[' Супер Протеин напиток белковый соевый сухой г банка '],
#  [' Канефрон Н таб.п.о.N '],
#  [' Аторис табл. п.о.  мг. № '],
#  [' Уролесан капли д/приема внутрь фл.мл № '],
#  [' Немозол сусп. д/приема внутрь мг/мл фл. мл '],
#  [' Омник капс ,мг № '],
#  [' Бел Беби вкладыши для бюстгалтера № '],
#  [' Небилет таб.мг № '],
#  [' Эналаприл-ФПО таб.мг № '],
#  [' Бисопролол таб.п.п.о. мг № '],
#  [' Торасемид-СЗ таб.мг № '],
#  [' Фелодип табл. п.о. замедл. высв.  мг. № '],
#  [' Простамол Уно капс.  мг. № ']]

# %%
def poisk_id1 (zapros):
   lst = []
   lst_id = []
   lst_final=[]
   for k,v in Product_dict.items():
       lst.append((k,v))
   for lek in lst:
       if zapros.lower() in lek[1].lower():
           lst_id.append(lek[0])
   for el in lst_id:
       lst_final.append(list((data['id'][data.product_id == el])))
   vector= lst_final[0][0]
   vec = np.zeros(100)
   for word in vector.split(' '):
       if word in model:
           vec += model[word]

   data_storage_norm1 = vec
   annoy_res = list(index_img_emb.get_nns_by_vector(data_storage_norm1, 13, include_distances=True, search_k=10000))
   print('\n\nСоседи:')
   a = list()
   for annoy_id, annoy_sim in itertools.islice(zip(*annoy_res), 13):
       image_id = map_id_hashimg[annoy_id]
       # print(image_id)
       # print(data_storage[image_id], 1 - annoy_sim ** 2 / 2)
       a.append(list(prod1.loc[prod1['index'] == str(image_id)]['0']))

   return a

# %%
poisk_id1('Колдрекс')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:15: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   from ipykernel import kernelapp as app
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:16: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   app.launch_new_instance()
# Соседи:
# [[' Нео-Ангин Н тб N '],
#  [' Валтрекс табл. п.о.  мг. № '],
#  [' Тантум верде таб.д/рассасывания мг Апельсин-Мед № '],
#  [' Валвир таб.п.п.о. мг № '],
#  [' Гексорал таб. № '],
#  [' Стрепсилс тб.д/рассас. д/детей Лимон № '],
#  [' Валвир таб.п.п.о. мг № '],
#  [' Ринзасип с вит. С пор.д/приг.р-ра д/приема внутрь Черная Смородина саше г № '],
#  [' Бромгексин-Акрихин сироп мг/мл мл фл № '],
#  [' Снуп спрей наз. ,% фл.мл '],
#  [' Стопгрипан форте пор.д/пригот.р-ра Лимон № '],
#  [' Септолете Тотал таб.д/рассас. Мед-Лимон № '],
#  [' Валцикон таб.п.п.о. мг № ']]

# %%
def find_similar_subgroup(a=134832):
    pr = data.loc[data['product_id'] == str(a)]
    pr.reset_index(inplace=True, drop=False)
    vector = pr['id'][0]
    group = pr['product_sub_category_id'][0]
    print(group)
    vec = np.zeros(100)
    for word in vector.split(' '):
        if word in model:
            vec += model[word]

    data_storage_norm1 = vec
    annoy_res = list(index_img_emb.get_nns_by_vector(data_storage_norm1, 500, include_distances=True, search_k=10000))
    a = list()
    d = (data.loc[data['product_sub_category_id'] == str (group)])
    for annoy_id, annoy_sim in itertools.islice(zip(*annoy_res), 500):
        image_id = map_id_hashimg[annoy_id]
        # print(image_id)
        # print(data_storage[image_id], 1 - annoy_sim ** 2 / 2)
        if(any(d['product_id'] == image_id)):
       
            a.append(list(prod1.loc[prod1['index'] == str(image_id)]['0']))
    return a

# %%
find_similar_subgroup()
# Out:
# 404
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if __name__ == '__main__':
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   # Remove the CWD from sys.path while we load stuff.
# [[' МестаМидин-сенс р-р д/местного и наруж.прим.фл-спрей б/канюлимл '],
#  [' Бриллиантовый зеленый р-р спирт % фл мл N с винтовой крышкой '],
#  [' Эплан крем г N '],
#  [' PL Салфетка антисептическая спиртовая хсм № '],
#  [' Формидрон жидк фл мл N '],
#  [' Салициловая кислота р-р спирт % фл мл N '],
#  [' Борная кислота пор г уп N '],
#  [' '],
#  [' Салициловая кислота р-р спирт % фл мл N '],
#  [' Люголя раствор с глицерином р-р фл г N ']]

# %%
# Out:
# str

# %%
# Out:
# 906
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if __name__ == '__main__':
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   # Remove the CWD from sys.path while we load stuff.
# [[' Пакет-майка см х см '],
#  [' Пакет "Майка" х/см '],
#  [' Пакет майка  х см '],
#  [' Пакеты п/э хсм с выруб ручкой N '],
#  [' Пакет НД "Майка" х '],
#  [' Пакет  хсм № '],
#  [' Пакет "Аптека Озерки"  х см '],
#  [' Пакет "Майка" х/см '],
#  [' Пакеты маленькие '],
#  [' Пакет-сумка бум. ххсм '],
#  [' Пакет "Аптека Озерки"  х см ПНД '],
#  [' Пакет "Озерки Дрогери"  х см ПНД '],
#  [' Пакет "Озерки Дрогери"  х см ПНД ']]
